# %% [markdown]
# # Imports and Constants

# %%
import csv
from pandas import DataFrame, read_csv
import pandas as pd
import matplotlib.pyplot as plt
from textwrap import wrap
import numpy as np
from __future__ import print_function
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})

# %%
output_file_path = "output.csv"
input_file_path = "Inpatient_Prospective_Payment_System__IPPS__Provider_Summary_for_the_Top_100_Diagnosis-Related_Groups__DRG__-_FY2011.csv"

# %%
drgDef = 'DRG Definition'
providerId = 'Provider Id'
providerName = 'Provider Name'
providerStreet = 'Provider Street Address'
providerCity= 'Provider City'
providerState = 'Provider State'
providerZip = 'Provider Zip Code'
hospRef = 'Hospital Referral Region Description'
totalDischarges = ' Total Discharges '
avgCovered = ' Average Covered Charges '
avgTotal = ' Average Total Payments '
avgMedicare = 'Average Medicare Payments'

# %%
header_list = [drgDef, providerId, providerName, providerStreet, providerCity,providerState, 
               providerZip, hospRef, totalDischarges, avgCovered, avgTotal, avgMedicare]

# %% [markdown]
# # Data Refining

# %%
def refine_dataset(dataSet):
    """
        Prints type of each variable in the dataSet as well as the occurences of
        each unique value

        :param DataFrame dataSet: The DataFrame to refine
        :return: refined dataSet
        :rtype: DataFrame
    """
    #Drops rows with invalid number of variables
    dataSet.dropna(how='any')

    #Write updated dataset to file (For sake of testing comment this out, it's quite slow)
    dataSet.to_csv(output_file_path);

    return dataSet

dataSet = refine_dataset(dataSet)

# %% [markdown]
# # Basic Data Analysis

# %%
def descriptive_analysis(dataSet):
    """
        Prints the number of records in a dataSet
        the type of each varaible
        and the occurrences of each unique value
        
        :param DataFrame dataSet: The DataFrame to print stats for
    """
    
    print("\nNumber of records: " + str(len(dataSet)) + "\n")
    
    #Seems janky but does the job,
    #removes person from list (Does not have any effect on given dataSet)
    for headerName in dataSet:
        # Get group for current header
        group = dataSet.groupby(headerName)

        # Print number of occurrences of each variable
        print(group.size())
        print("\n")

descriptive_analysis(dataSet)
# Out:
# Number of records: 163065
#
# DRG Definition
# 039 - EXTRACRANIAL PROCEDURES W/O CC/MCC                                      1079
# 057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC                           1201
# 064 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W MCC                    1659
# 065 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W CC                     2269
# 066 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W/O CC/MCC               1806
# 069 - TRANSIENT ISCHEMIA                                                      1962
# 074 - CRANIAL & PERIPHERAL NERVE DISORDERS W/O MCC                             979
# 101 - SEIZURES W/O MCC                                                        1593
# 149 - DYSEQUILIBRIUM                                                           988
# 176 - PULMONARY EMBOLISM W/O MCC                                              1396
# 177 - RESPIRATORY INFECTIONS & INFLAMMATIONS W MCC                            1894
# 178 - RESPIRATORY INFECTIONS & INFLAMMATIONS W CC                             1953
# 189 - PULMONARY EDEMA & RESPIRATORY FAILURE                                   2096
# 190 - CHRONIC OBSTRUCTIVE PULMONARY DISEASE W MCC                             2713
# 191 - CHRONIC OBSTRUCTIVE PULMONARY DISEASE W CC                              2720
# 192 - CHRONIC OBSTRUCTIVE PULMONARY DISEASE W/O CC/MCC                        2671
# 193 - SIMPLE PNEUMONIA & PLEURISY W MCC                                       2575
# 194 - SIMPLE PNEUMONIA & PLEURISY W CC                                        3023
# 195 - SIMPLE PNEUMONIA & PLEURISY W/O CC/MCC                                  2576
# 202 - BRONCHITIS & ASTHMA W CC/MCC                                            1384
# 203 - BRONCHITIS & ASTHMA W/O CC/MCC                                           894
# 207 - RESPIRATORY SYSTEM DIAGNOSIS W VENTILATOR SUPPORT 96+ HOURS             1163
# 208 - RESPIRATORY SYSTEM DIAGNOSIS W VENTILATOR SUPPORT <96 HOURS             1993
# 238 - MAJOR CARDIOVASC PROCEDURES W/O MCC                                     1054
# 243 - PERMANENT CARDIAC PACEMAKER IMPLANT W CC                                1150
# 244 - PERMANENT CARDIAC PACEMAKER IMPLANT W/O CC/MCC                          1075
# 246 - PERC CARDIOVASC PROC W DRUG-ELUTING STENT W MCC OR 4+ VESSELS/STENTS     917
# 247 - PERC CARDIOVASC PROC W DRUG-ELUTING STENT W/O MCC                       1408
# 249 - PERC CARDIOVASC PROC W NON-DRUG-ELUTING STENT W/O MCC                    955
# 251 - PERC CARDIOVASC PROC W/O CORONARY ARTERY STENT W/O MCC                   727
#                                                                               ...
# 480 - HIP & FEMUR PROCEDURES EXCEPT MAJOR JOINT W MCC                          929
# 481 - HIP & FEMUR PROCEDURES EXCEPT MAJOR JOINT W CC                          2090
# 482 - HIP & FEMUR PROCEDURES EXCEPT MAJOR JOINT W/O CC/MCC                    1040
# 491 - BACK & NECK PROC EXC SPINAL FUSION W/O CC/MCC                            975
# 536 - FRACTURES OF HIP & PELVIS W/O MCC                                       1142
# 552 - MEDICAL BACK PROBLEMS W/O MCC                                           1801
# 563 - FX, SPRN, STRN & DISL EXCEPT FEMUR, HIP, PELVIS & THIGH W/O MCC          984
# 602 - CELLULITIS W MCC                                                         945
# 603 - CELLULITIS W/O MCC                                                      2807
# 638 - DIABETES W CC                                                           1820
# 640 - MISC DISORDERS OF NUTRITION,METABOLISM,FLUIDS/ELECTROLYTES W MCC        1752
# 641 - MISC DISORDERS OF NUTRITION,METABOLISM,FLUIDS/ELECTROLYTES W/O MCC      2899
# 682 - RENAL FAILURE W MCC                                                     2144
# 683 - RENAL FAILURE W CC                                                      2508
# 684 - RENAL FAILURE W/O CC/MCC                                                1008
# 689 - KIDNEY & URINARY TRACT INFECTIONS W MCC                                 1952
# 690 - KIDNEY & URINARY TRACT INFECTIONS W/O MCC                               2989
# 698 - OTHER KIDNEY & URINARY TRACT DIAGNOSES W MCC                             874
# 699 - OTHER KIDNEY & URINARY TRACT DIAGNOSES W CC                              920
# 811 - RED BLOOD CELL DISORDERS W MCC                                          1135
# 812 - RED BLOOD CELL DISORDERS W/O MCC                                        2321
# 853 - INFECTIOUS & PARASITIC DISEASES W O.R. PROCEDURE W MCC                  1376
# 870 - SEPTICEMIA OR SEVERE SEPSIS W MV 96+ HOURS                               939
# 871 - SEPTICEMIA OR SEVERE SEPSIS W/O MV 96+ HOURS W MCC                      2812
# 872 - SEPTICEMIA OR SEVERE SEPSIS W/O MV 96+ HOURS W/O MCC                    2505
# 885 - PSYCHOSES                                                                613
# 897 - ALCOHOL/DRUG ABUSE OR DEPENDENCE W/O REHABILITATION THERAPY W/O MCC      906
# 917 - POISONING & TOXIC EFFECTS OF DRUGS W MCC                                 843
# 918 - POISONING & TOXIC EFFECTS OF DRUGS W/O MCC                              1382
# 948 - SIGNS & SYMPTOMS W/O MCC                                                1793
# dtype: int64
#
#
# Provider Id
# 10001     92
# 10005     49
# 10006     86
# 10007     22
# 10008      9
# 10009     17
# 10010     45
# 10011     87
# 10012     33
# 10015      7
# 10016     80
# 10019     62
# 10021     18
# 10022     10
# 10023     92
# 10024     83
# 10025     36
# 10027      7
# 10029     93
# 10032      8
# 10033     97
# 10034     19
# 10035     68
# 10036     32
# 10038     54
# 10039     99
# 10040     79
# 10043      9
# 10044     11
# 10045     19
#           ..
# 670023    35
# 670024    66
# 670025    19
# 670029     1
# 670031    28
# 670034    48
# 670041    58
# 670043    20
# 670044    28
# 670046     2
# 670047    40
# 670049     3
# 670050     4
# 670052     7
# 670053    24
# YAVAPAI REGIONAL MEDICAL CENTER-EAST              27
# YORK HOSPITAL                                    140
# YUKON KUSKOKWIM DELTA REG HOSPITAL                 6
# YUMA REGIONAL MEDICAL CENTER                      87
# ZUNI COMPREHENSIVE COMMUNITY HEALTH CENTER         1
# dtype: int64
#
#
# Provider Street Address
# #1 MEDICAL PARK DRIVE                   51
# #3 EAST BENJAMIN DRIVE                  10
# 1 ABRAHMS BOULEVARD                      4
# 1 AMALIA DRIVE                          11
# 1 BOSTON MEDICAL CENTER PLACE           94
# 1 CHOCTAW WAY                            2
# 1 COOPER PLAZA                          88
# 1 EAST NEW YORK AVE                     81
# 1 ELLIOT WAY                            79
# 1 HOSPITAL DRIVE                        95
# 1 MEDICAL CENTER BOULEVARD              92
# 1 MEDICAL CENTER DR  PO BOX 139         35
# 1 MEDICAL CENTER DRIVE                 142
# 1 MEDICAL PARK                          60
# 1 MEDICAL PARK DRIVE                    15
# 1 MEDICAL PLAZA                         28
# 1 MT CARMEL WAY                         39
# 1 N ATKINSON DRIVE                      25
# 1 PARKLAND DRIVE                        42
# 1 SHIRCLIFF WAY                         98
# 1 TAMPA GENERAL CIRCLE                  94
# 10 HOSPITAL DR                          53
# 10 HOSPITAL ST BOX 550                  21
# 10 SOUTH HOSPITAL DRIVE                  6
# 10 WOODLAND ROAD                        50
# 100  15TH ST NW                         30
# 100 A ALTON GLOOR                       59
# 100 AIRPORT RD                          65
# 100 BROWN ST                            39
# 100 DOCTOR WARREN TUTTLE DR             23
#                                       ...
# P O BOX 948/427 HIGHWAY 51 NORTH        28
# PO BOX 128/150 REYNOIR STREET           53
# PO BOX 1484                             52
# PO BOX 160                               2
# PO BOX 200                               1
# PO BOX 287                               6
# PO BOX 3708 DUMC  ERWIN RD              97
# PO BOX 527                              67
# PO BOX 588  811  REYNOLDS ROAD           8
# PO BOX 59                               41
# PO BOX 600                              14
# PO BOX 649                               7
# PO BOX 650 BUS HWY 65 & SKAGGS RD       61
# PO BOX 689                              98
# POWELL & FORNANCE STREETS               45
# ROUTE 301 NORTH                          1
# SIXTH AVENUE AND SPRUCE ST              95
# ST ANTHONY'S WAY                        35
# TAYLOR AT MARION                        65
# TWO CRESCENT PARK WEST                  30
# TWO ST VINCENT CIRCLE                   92
# TWO STONE HARBOR BLVD                   78
# US HWY 191, HOSPITAL ROAD                7
# US HWY 491 NORTH                         9
# US HWY 76 PO DRAWER 976                 34
# W 800 FIFTH AVENUE                      72
# W180 N8085 TOWN HALL RD                 68
# W3985 CTY RD NN                         32
# WHITEHORSE PIKE AND TOWNSEND AVENUE     98
# WILKENS & CATON AVENUES                 97
# dtype: int64
#
#
# Provider City
# ABBEVILLE          18
# ABERDEEN          107
# ABILENE           152
# ABINGDON           63
# ABINGTON           99
# ADA                40
# ADDISON             4
# ADEL                9
# ADRIAN             40
# AHOSKIE            46
# AIEA               50
# AIKEN              79
# AKRON             193
# ALABASTER          80
# ALAMEDA            30
# ALAMOGORDO         35
# ALAMOSA            16
# ALBANY            390
# ALBEMARLE          43
# ALBERT LEA         26
# ALBUQUERQUE       271
# ALEXANDER CITY     40
# ALEXANDRIA        344
# ALHAMBRA           33
# ALICE              27
# ALLEN              21
# ALLENTOWN         138
# ALLIANCE           37
# ALMA               47
# ALPENA             52
#                  ...
# WOODLAND           11
# WOODLAND HILLS      1
# WOODRUFF           25
# WOODSTOCK          62
# WOODVILLE          14
# WOODWARD           17
# WOONSOCKET         51
# WOOSTER            42
# WORCESTER         179
# WORTHINGTON        10
# WYANDOTTE          92
# WYNNEWOOD          95
# WYOMING            92
# WYOMISSING          2
# WYTHEVILLE         27
# XENIA              35
# YAKIMA            142
# YANKTON            41
# YONKERS           130
# YORK              197
# YOUNGSTOWN        148
# YUBA CITY           1
# YUKON              21
# YUMA               87
# ZACHARY            33
# ZANESVILLE         96
# ZEELAND            11
# ZEPHYRHILLS        80
# ZION                2
# ZUNI                1
# dtype: int64
#
#
# Provider State
# AK      231
# AL     3635
# AR     2067
# AZ     2851
# CA    13064
# CO     1890
# CT     2011
# DC      462
# DE      394
# FL    11155
# GA     4968
# HI      442
# IA     1734
# ID      551
# IL     7909
# IN     4260
# KS     1638
# KY     3229
# LA     3027
# MA     3842
# MD     3330
# ME      888
# MI     5419
# MN     2252
# MO     4059
# MS     2410
# MT      506
# NC     5041
# ND      422
# NE     1062
# NH      823
# NJ     4826
# NM      917
# NV     1202
# NY     9178
# OH     7012
# OK     2520
# OR     1299
# PA     7804
# RI      588
# SC     2847
# SD      486
# TN     4168
# TX    11864
# UT      732
# VA     4332
# VT      270
# WA     2778
# WI     2834
# WV     1589
# WY      247
# dtype: int64
#
#
# Provider Zip Code
# 1040      59
# 1060      62
# 1069      38
# 1082      13
# 1085      36
# 1104      73
# 1199      98
# 1201      84
# 1247      20
# 1301      35
# 1432      23
# 1440      37
# 1453      45
# 1510      11
# 1550      35
# 1605       1
# 1608      78
# 1655     100
# 1701      87
# 1742      53
# 1752      38
# 1757      71
# 1803      98
# 1830      48
# 1842      81
# 1844      74
# 1852      69
# 1854      74
# 1890      76
# 1915      82
#         ...
# 98405     91
# 98415     89
# 98499     65
# 98502     30
# 98506     89
# 98520     52
# 98531     46
# 98632     58
# 98668     92
# 98686     51
# 98801      6
# 98807     79
# 98837     22
# 98902    142
# 98948      8
# 99204     90
# 99208     61
# 99210     72
# 99216     50
# 99336     42
# 99352     79
# 99362     49
# 99508     59
# 99519     76
# 99559      6
# 99645     32
# 99669     18
# 99701     29
# 99801     10
# 99835      1
# dtype: int64
#
#
# Hospital Referral Region Description
# AK - Anchorage                 231
# AL - Birmingham               1881
# AL - Dothan                    340
# AL - Huntsville                407
# AL - Mobile                    552
# AL - Montgomery                365
# AL - Tuscaloosa                172
# AR - Fort Smith                250
# AR - Jonesboro                 255
# AR - Little Rock              1178
# AR - Springdale                287
# AR - Texarkana                 210
# AZ - Mesa                      492
# AZ - Phoenix                  1519
# AZ - Sun City                  191
# AZ - Tucson                    550
# CA - Alameda County            495
# CA - Bakersfield               474
# CA - Chico                     239
# CA - Contra Costa County       354
# CA - Fresno                    350
# CA - Los Angeles              3653
# CA - Modesto                   365
# CA - Napa                      150
# CA - Orange County             991
# CA - Palm Springs/Rancho M     195
# CA - Redding                   227
# CA - Sacramento                903
# $10001.25     1
# $10001.40     2
# $10001.44     1
# $10001.46     1
# $10001.63     1
# $10001.76     1
# $100018.33    1
# $10002.13     1
# $10002.15     1
# $10002.22     1
# $10002.31     1
# $10002.35     1
#              ..
# $9995.40      1
# $9995.92      1
# $9995.96      1
# $9996.04      1
# $9996.14      1
# $9996.19      1
# $9996.26      1
# $9996.29      1
# $9996.70      2
# $9996.79      1
# $9997.00      1
# $9997.07      1
# $9997.11      1
# $9997.46      1
# $9997.50      1
# $9997.54      1
# $9997.61      1
# $9997.84      1
# $9997.96      1
# $9998.03      1
# $9998.13      1
# $9998.15      1
# $9998.21      1
# $9998.23      1
# $9998.43      1
# $9998.83      1
# $9999.35      1
# $9999.51      1
# $9999.92      1
# $9999.95      1
# dtype: int64
#
#
# Average Medicare Payments
# $10000.09    1
# $10000.35    2
# $10000.91    2
# $10001.03    1
# $10001.16    1
# $10001.30    1
# $10001.35    1
# $10001.43    1
# $10001.78    1
# $10001.79    1
# $10002.20    1
# $10002.35    1
# $10002.41    1
# $10002.42    1
# $10002.50    1
# $10002.51    1
# $10002.52    1
# $10002.81    1
# $10003.20    1
# $10003.22    1
# $10003.36    1
# $10003.40    1
# $10003.43    1
# $10003.50    1
# $10003.71    1
# $10004.18    1
# $10004.48    1
# $10004.56    1
# $10004.60    1
# $10004.68    1
#             ..
# $9997.57     1
# $9997.58     1
# $9997.72     1
# $9997.77     1
# $9997.81     1
# $9997.82     1
# $9997.95     1
# $9998.00     1
# $9998.09     1
# $9998.36     1
# $9998.42     1
# $9998.53     1
# $9998.70     1
# $9998.72     1
# $9998.75     1
# $9998.79     1
# $9998.82     1
# $9998.84     1
# $9998.91     1
# $9998.96     1
# $9999.10     1
# $9999.24     1
# $9999.37     1
# $9999.46     1
# $9999.51     1
# $9999.58     2
# $9999.70     1
# $9999.81     1
# $9999.86     1
# $9999.88     1
# dtype: int64

# %% [markdown]
# # Data Plotting Methods

# %% [markdown]
# Plot pie chart of distribution by a given header name

# %%
def plot_pie_distribution_by_header(dataSet, header):
    """
        Takes dataSet and plots distribution of given header

        :param DataFrame dataSet: The DataFrame to be plotted
    """
    # %matplotlib notebook

    fig, axis = plt.subplots()
    
    title = "Distribution of " + header
    
    dataSet[header].value_counts().plot(ax=axis, kind='pie')
    plt.ylabel("")
    #plt.tight_layout()
    plt.title(title, y=1.02)
    axis.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.savefig('Visualisations/distribution.png')
    plt.show()

# %% [markdown]
# Plot bar graph of distribution by a given header name

# %%
def plot_bar_distribution_by_header(dataSet, header):
    """
        Takes dataSet and plots distribution of given header

        :param DataFrame dataSet: The DataFrame to be plotted
    """
    # %matplotlib notebook

    fig, axis = plt.subplots()
    
    title = "Distribution of " + header
    
    filename = 'Visualisations/distribution_of_' + header.replace(" ", "_") + '.png'
    
    dataSet[header].value_counts().plot(ax=axis, kind='bar')
    plt.ylabel("")
    #plt.tight_layout()
    plt.title(title, y=1.02)  # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.savefig(filename)
    plt.show()

# %% [markdown]
# # Data Analysis Execution

# %%
dataSet = pd.read_csv(input_file_path, header=0)

# %%
plot_bar_distribution_by_header(dataSet, providerState)
# Out:
# <img src="data:image/png;base64,...">
